# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full,
                                                  test_size=0.2,
                                                  random_state=123)


# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# 데이터 중 샘플 하나를 시각화해보고, 데이터의 형태를 확인해봅니다.
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
import numpy as np

x_train = np.reshape(x_train, (-1, 32 * 32 * 3))
x_val = np.reshape(x_val, (-1, 32 * 32 * 3))
x_test = np.reshape(x_test, (-1, 32 * 32 * 3))

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()
model.add(layers.Input(shape=(3072, )))
model.add(layers.Dense(2048))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1024))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='softmax'))


model.compile(optimizer='Adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2048)              6293504
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 8,935,946
# Trainable params: 8,928,778
# Non-trainable params: 7,168
# _________________________________________________________________

# %%
from tensorflow.keras import utils

utils.plot_model(model, show_shapes=True)

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
from tensorflow.keras import callbacks

check_point_cb = callbacks.ModelCheckpoint('cifar10_model.h5', save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=50, monitor='val_loss', restore_best_weights=True)

history = model.fit(x_train, y_train, epochs=50,
                    batch_size=720,
                    validation_data=(x_val, y_val),
                    callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/50
# 56/56 [==============================] - 3s 27ms/step - loss: 1.8988 - accuracy: 0.3411 - val_loss: 3.2933 - val_accuracy: 0.2054
# Epoch 2/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.5987 - accuracy: 0.4309 - val_loss: 1.8489 - val_accuracy: 0.3438
# Epoch 3/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.4682 - accuracy: 0.4730 - val_loss: 1.8781 - val_accuracy: 0.3448
# Epoch 4/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.3868 - accuracy: 0.5053 - val_loss: 1.9351 - val_accuracy: 0.3312
# Epoch 5/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.3185 - accuracy: 0.5279 - val_loss: 1.8141 - val_accuracy: 0.3538
# Epoch 6/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.2571 - accuracy: 0.5526 - val_loss: 1.8426 - val_accuracy: 0.3565
# Epoch 7/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.2008 - accuracy: 0.5693 - val_loss: 1.7250 - val_accuracy: 0.3916
# Epoch 8/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.1587 - accuracy: 0.5846 - val_loss: 1.6802 - val_accuracy: 0.4069
# Epoch 9/50
# 56/56 [==============================] - 1s 16ms/step - loss: 1.1183 - accuracy: 0.6008 - val_loss: 1.7631 - val_accuracy: 0.3912
# Epoch 10/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.0701 - accuracy: 0.6184 - val_loss: 1.7035 - val_accuracy: 0.4028
# Epoch 11/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.0344 - accuracy: 0.6307 - val_loss: 1.7684 - val_accuracy: 0.3766
# Epoch 12/50
# 56/56 [==============================] - 1s 15ms/step - loss: 1.0003 - accuracy: 0.6444 - val_loss: 1.6738 - val_accuracy: 0.4072
# Epoch 13/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.9552 - accuracy: 0.6578 - val_loss: 1.6624 - val_accuracy: 0.4233
# Epoch 14/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.9211 - accuracy: 0.6707 - val_loss: 1.5560 - val_accuracy: 0.4653
# Epoch 15/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.8901 - accuracy: 0.6823 - val_loss: 1.5998 - val_accuracy: 0.4441
# Epoch 16/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.8521 - accuracy: 0.6969 - val_loss: 1.6974 - val_accuracy: 0.4017
# Epoch 17/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.8166 - accuracy: 0.7095 - val_loss: 1.5796 - val_accuracy: 0.4455
# Epoch 18/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.7949 - accuracy: 0.7142 - val_loss: 1.9774 - val_accuracy: 0.3989
# Epoch 19/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.7641 - accuracy: 0.7265 - val_loss: 1.7418 - val_accuracy: 0.4460
# Epoch 20/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.7315 - accuracy: 0.7379 - val_loss: 2.1050 - val_accuracy: 0.3857
# Epoch 21/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.6936 - accuracy: 0.7521 - val_loss: 2.4532 - val_accuracy: 0.3625
# Epoch 22/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.6735 - accuracy: 0.7594 - val_loss: 1.6360 - val_accuracy: 0.4591
# Epoch 23/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.6379 - accuracy: 0.7711 - val_loss: 1.9266 - val_accuracy: 0.4293
# Epoch 24/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.6178 - accuracy: 0.7800 - val_loss: 1.9231 - val_accuracy: 0.4376
# Epoch 25/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5846 - accuracy: 0.7906 - val_loss: 1.8830 - val_accuracy: 0.4386
# Epoch 26/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5642 - accuracy: 0.7981 - val_loss: 1.9309 - val_accuracy: 0.4346
# Epoch 27/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5393 - accuracy: 0.8066 - val_loss: 1.9614 - val_accuracy: 0.4255
# Epoch 28/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5155 - accuracy: 0.8147 - val_loss: 1.7244 - val_accuracy: 0.4539
# Epoch 29/50
# 56/56 [==============================] - 1s 16ms/step - loss: 0.4967 - accuracy: 0.8221 - val_loss: 1.7225 - val_accuracy: 0.4871
# Epoch 30/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4726 - accuracy: 0.8314 - val_loss: 1.6777 - val_accuracy: 0.4499
# Epoch 31/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4481 - accuracy: 0.8397 - val_loss: 1.7810 - val_accuracy: 0.4816
# Epoch 32/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4362 - accuracy: 0.8429 - val_loss: 3.0611 - val_accuracy: 0.3612
# Epoch 33/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4201 - accuracy: 0.8503 - val_loss: 1.9376 - val_accuracy: 0.4800
# Epoch 34/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3950 - accuracy: 0.8587 - val_loss: 2.1178 - val_accuracy: 0.4725
# Epoch 35/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3853 - accuracy: 0.8634 - val_loss: 2.9030 - val_accuracy: 0.3953
# Epoch 36/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3631 - accuracy: 0.8711 - val_loss: 2.0673 - val_accuracy: 0.4619
# Epoch 37/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3542 - accuracy: 0.8734 - val_loss: 2.7465 - val_accuracy: 0.4128
# Epoch 38/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3407 - accuracy: 0.8763 - val_loss: 2.8214 - val_accuracy: 0.4264
# Epoch 39/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3434 - accuracy: 0.8778 - val_loss: 2.2971 - val_accuracy: 0.4686
# Epoch 40/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3106 - accuracy: 0.8880 - val_loss: 2.4733 - val_accuracy: 0.4381
# Epoch 41/50
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3032 - accuracy: 0.8931 - val_loss: 2.5638 - val_accuracy: 0.4407
# Epoch 42/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2937 - accuracy: 0.8954 - val_loss: 2.5750 - val_accuracy: 0.4440
# Epoch 43/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2743 - accuracy: 0.9020 - val_loss: 2.5871 - val_accuracy: 0.4457
# Epoch 44/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2687 - accuracy: 0.9047 - val_loss: 2.1721 - val_accuracy: 0.4741
# Epoch 45/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2644 - accuracy: 0.9060 - val_loss: 2.0706 - val_accuracy: 0.4894
# Epoch 46/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2489 - accuracy: 0.9109 - val_loss: 2.4958 - val_accuracy: 0.4540
# Epoch 47/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2474 - accuracy: 0.9113 - val_loss: 2.6369 - val_accuracy: 0.4635
# Epoch 48/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2472 - accuracy: 0.9128 - val_loss: 2.3587 - val_accuracy: 0.4737
# Epoch 49/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2435 - accuracy: 0.9135 - val_loss: 3.0454 - val_accuracy: 0.4463
# Epoch 50/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2257 - accuracy: 0.9206 - val_loss: 2.4671 - val_accuracy: 0.4481

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4659 - accuracy: 0.4524
# [2.4659202098846436, 0.45239999890327454]
